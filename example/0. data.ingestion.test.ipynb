# %%
import pandas as pd
import os
import sys
sys.path.append("../")
sys.path.append("../../")
from setting import influx_setting_KETI as ins

# %% [markdown]
# # Data Ingestion Initialization

# %% [markdown]
# ## DB Client

# %%
version = 2 # or 1

if version == 1: 
    from clust.data.ingestion.influx import influx_Client as influx_Client
    dataServer = ins.CLUSTDataServer
elif version == 2:
    from clust.data.ingestion.influx import influx_Client_v2 as influx_Client
    dataServer = ins.CLUSTDataServer2

DBClient = influx_Client.influxClient(dataServer)

# %%
db_list = DBClient.get_DBList()

# %% [markdown]
# ## DB MS Frequency

# %%
db_name ='air_indoor_중학교'
ms_name = DBClient.measurement_list(db_name)[0]

# %%
ms_list = DBClient.measurement_list(db_name)
ms_list
# Out:
# ['ICW0W2000010',
#  'ICW0W2000011',
#  'ICW0W2000012',
#  'ICW0W2000013',
#  'ICW0W2000014',
#  'ICW0W2000015',
#  'ICW0W2000016',
#  'ICW0W2000017',
#  'ICW0W2000018',
#  'ICW0W2000019',
#  'ICW0W2000020']

# %%
freq = DBClient.get_freq(db_name, ms_name)

# %% [markdown]
# ## DB and Measurement name setting

# %%
db_name  = 'bio_covid_infected_world'

# %%
ms_list = DBClient.measurement_list(db_name)
print(ms_list)
# Out:
# ['argentina', 'australia', 'england', 'france', 'germany', 'japan', 'korea', 'south_africa', 'spain', 'usa']

# %%
ms_list_only = DBClient.measurement_list_only_start_end(db_name)
ms_list_only
# Out:
# ['argentina', '...(+8)', 'usa']

# %%
ms_name = 'england'

# %%
tag_list = DBClient.get_tagList(db_name, ms_name)

# %% [markdown]
# # Data Ingestion Methods

# %% [markdown]
# ## pure data ingestion

# %% [markdown]
# ### Ingest Full Data

# %%
print(db_name, ms_name)
# Out:
# bio_covid_infected_world england

# %%
feature_list = DBClient.get_fieldList(db_name, ms_name)
print(feature_list)
# Out:
# ['confirmed', 'deaths']

# %%
full_data = DBClient.get_data(db_name, ms_name)
full_data
# Out:
#                            confirmed  deaths
# time
# 2020-01-22 00:00:00+00:00          0       0
# 2020-01-23 00:00:00+00:00          0       0
# 2020-01-24 00:00:00+00:00          0       0
# 2020-01-25 00:00:00+00:00          0       0
# 2020-01-26 00:00:00+00:00          0       0
# ...                              ...     ...
# 2021-11-03 00:00:00+00:00    9215683  141607
# 2021-11-04 00:00:00+00:00    9252646  141826
# 2021-11-05 00:00:00+00:00    9286618  142019
# 2021-11-06 00:00:00+00:00    9317072  142174
# 2021-11-07 00:00:00+00:00    9346961  142236
#
# [656 rows x 2 columns]

# %%
number = 100
data_front_number = DBClient.get_datafront_by_num(number, db_name, ms_name)
data_front_number
# Out:
#                            confirmed  deaths
# time
# 2020-01-22 00:00:00+00:00          0       0
# 2020-01-23 00:00:00+00:00          0       0
# 2020-01-24 00:00:00+00:00          0       0
# 2020-01-25 00:00:00+00:00          0       0
# 2020-01-26 00:00:00+00:00          0       0
# ...                              ...     ...
# 2020-04-26 00:00:00+00:00     158926   24053
# 2020-04-27 00:00:00+00:00     163630   24376
# 2020-04-28 00:00:00+00:00     168357   25347
# 2020-04-29 00:00:00+00:00     173807   26118
# 2020-04-30 00:00:00+00:00     178771   26754
#
# [100 rows x 2 columns]

# %%
number = 100
data_end_number = DBClient.get_dataend_by_num(number, db_name, ms_name)
data_end_number
# Out:
#                            confirmed  deaths
# time
# 2021-07-31 00:00:00+00:00    5883421  129949
# 2021-08-01 00:00:00+00:00    5907594  130014
# 2021-08-02 00:00:00+00:00    5929881  130039
# 2021-08-03 00:00:00+00:00    5951736  130179
# 2021-08-04 00:00:00+00:00    5980887  130300
# ...                              ...     ...
# 2021-11-03 00:00:00+00:00    9215683  141607
# 2021-11-04 00:00:00+00:00    9252646  141826
# 2021-11-05 00:00:00+00:00    9286618  142019
# 2021-11-06 00:00:00+00:00    9317072  142174
# 2021-11-07 00:00:00+00:00    9346961  142236
#
# [100 rows x 2 columns]

# %%
first = DBClient.get_first_time(db_name, ms_name)
last = DBClient.get_last_time(db_name, ms_name)
print(first)
print(last)
# Out:
# 2020-01-22 00:00:00+00:00
# 2021-11-07 00:00:00+00:00

# %%
end_time = last
start_time = first
time_data = DBClient.get_data_by_time(start_time, end_time, db_name, ms_name)
print(time_data.head())
print(time_data.tail())
# Out:
#                            confirmed  deaths
# time
# 2020-01-22 00:00:00+00:00          0       0
# 2020-01-23 00:00:00+00:00          0       0
# 2020-01-24 00:00:00+00:00          0       0
# 2020-01-25 00:00:00+00:00          0       0
# 2020-01-26 00:00:00+00:00          0       0
#                            confirmed  deaths
# time
# 2021-11-02 00:00:00+00:00    9174153  141390
# 2021-11-03 00:00:00+00:00    9215683  141607
# 2021-11-04 00:00:00+00:00    9252646  141826
# 2021-11-05 00:00:00+00:00    9286618  142019
# 2021-11-06 00:00:00+00:00    9317072  142174

# %%
days = 7 
day_data = DBClient.get_data_by_days(end_time, str(days)+'d', db_name, ms_name)
print(day_data.head())
print(day_data.tail())
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Input In [30], in <cell line: 2>()
#       1 days = 7
# ----> 2 day_data = DBClient.get_data_by_days(end_time, str(days)+'d', db_name, ms_name)
#       3 print(day_data.head())
#       4 print(day_data.tail())
#
# File ~/CLUST_KETI/Clust/Clust/example/../clust/data/ingestion/influx/influx_Client_v2.py:338, in influxClient.get_data_by_days(self, end_time, days, bk_name, ms_name, tag_key, tag_value)
#     329     query = f'''
#     330     import "experimental"
#     331     from(bucket: "{bk_name}")
#    (...)
#     335     |> pivot(rowKey:["_time"], columnKey: ["_field"], valueColumn: "_value")
#     336     '''
#     337 query_client = self.DBClient.query_api()
# --> 338 data_frame = query_client.query_data_frame(query=query)
#     339 data_frame = self.cleanup_df(data_frame)
#     341 return data_frame
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/influxdb_client/client/query_api.py:126, in QueryApi.query_data_frame(self, query, org, data_frame_index, params)
#     111 def query_data_frame(self, query: str, org=None, data_frame_index: List[str] = None, params: dict = None):
#     112     """
#     113     Execute synchronous Flux query and return Pandas DataFrame.
#     114
#    (...)
#     124     :return: DataFrame or List of DataFrames
#     125     """
# --> 126     _generator = self.query_data_frame_stream(query, org=org, data_frame_index=data_frame_index, params=params)
#     127     return self._to_data_frames(_generator)
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/influxdb_client/client/query_api.py:146, in QueryApi.query_data_frame_stream(self, query, org, data_frame_index, params)
#     130 """
#     131 Execute synchronous Flux query and return stream of Pandas DataFrame as a Generator['pd.DataFrame'].
#     132
#    (...)
#     142 :return:
#     143 """
#     144 org = self._org_param(org)
# --> 146 response = self._query_api.post_query(org=org, query=self._create_query(query, self.default_dialect, params),
#     147                                       async_req=False, _preload_content=False, _return_http_data_only=False)
#     149 return self._to_data_frame_stream(data_frame_index=data_frame_index,
#     150                                   response=response,
#     151                                   query_options=self._get_query_options())
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/influxdb_client/service/query_service.py:281, in QueryService.post_query(self, **kwargs)
#     279     return self.post_query_with_http_info(**kwargs)  # noqa: E501
#     280 else:
# --> 281     (data) = self.post_query_with_http_info(**kwargs)  # noqa: E501
#     282     return data
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/influxdb_client/service/query_service.py:307, in QueryService.post_query_with_http_info(self, **kwargs)
#     285 """Query data.
#     286
#     287 Retrieves data from InfluxDB buckets.  To query data, you need the following: - **organization** – _See [View organizations](https://docs.influxdata.com/influxdb/v2.1/organizations/view-orgs/#view-your-organization-id) for instructions on viewing your organization ID._ - **API token** – _See [View tokens](https://docs.influxdata.com/influxdb/v2.1/security/tokens/view-tokens/)  for instructions on viewing your API token._ - **InfluxDB URL** – _See [InfluxDB URLs](https://docs.influxdata.com/influxdb/v2.1/reference/urls/)_. - **Flux query** – _See [Flux](https://docs.influxdata.com/flux/v0.x/)._  For more information and examples, see [Query with the InfluxDB API](https://docs.influxdata.com/influxdb/v2.1/query-data/execute-queries/influx-api/).
#    (...)
#     302          returns the request thread.
#     303 """  # noqa: E501
#     304 local_var_params, path_params, query_params, header_params, body_params = \
#     305     self._post_query_prepare(**kwargs)
# --> 307 return self.api_client.call_api(
#     308     '/api/v2/query', 'POST',
#     309     path_params,
#     310     query_params,
#     311     header_params,
#     312     body=body_params,
#     313     post_params=[],
#     314     files={},
#     315     response_type='str',  # noqa: E501
#     316     auth_settings=[],
#     317     async_req=local_var_params.get('async_req'),
#     318     _return_http_data_only=local_var_params.get('_return_http_data_only'),  # noqa: E501
#     319     _preload_content=local_var_params.get('_preload_content', True),
#     320     _request_timeout=local_var_params.get('_request_timeout'),
#     321     collection_formats={},
#     322     urlopen_kw=kwargs.get('urlopen_kw', None))
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/influxdb_client/_sync/api_client.py:341, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, urlopen_kw)
#     302 """Make the HTTP request (synchronous) and Return deserialized data.
#     303
#     304 To make an async_req request, set the async_req parameter.
#    (...)
#     338     then the method will return the response directly.
#     339 """
#     340 if not async_req:
# --> 341     return self.__call_api(resource_path, method,
#     342                            path_params, query_params, header_params,
#     343                            body, post_params, files,
#     344                            response_type, auth_settings,
#     345                            _return_http_data_only, collection_formats,
#     346                            _preload_content, _request_timeout, urlopen_kw)
#     347 else:
#     348     thread = self.pool.apply_async(self.__call_api, (resource_path,
#     349                                    method, path_params, query_params,
#     350                                    header_params, body,
#    (...)
#     354                                    collection_formats,
#     355                                    _preload_content, _request_timeout, urlopen_kw))
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/influxdb_client/_sync/api_client.py:171, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, urlopen_kw)
#     168 urlopen_kw = urlopen_kw or {}
#     170 # perform request and return response
# --> 171 response_data = self.request(
#     172     method, url, query_params=query_params, headers=header_params,
#     173     post_params=post_params, body=body,
#     174     _preload_content=_preload_content,
#     175     _request_timeout=_request_timeout, **urlopen_kw)
#     177 self.last_response = response_data
#     179 return_data = response_data
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/influxdb_client/_sync/api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout, **urlopen_kw)
#     377     return self.rest_client.OPTIONS(url,
#     378                                     query_params=query_params,
#     379                                     headers=headers,
#    (...)
#     383                                     body=body,
#     384                                     **urlopen_kw)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(url,
#     387                                  query_params=query_params,
#     388                                  headers=headers,
#     389                                  post_params=post_params,
#     390                                  _preload_content=_preload_content,
#     391                                  _request_timeout=_request_timeout,
#     392                                  body=body,
#     393                                  **urlopen_kw)
#     394 elif method == "PUT":
#     395     return self.rest_client.PUT(url,
#     396                                 query_params=query_params,
#     397                                 headers=headers,
#    (...)
#     401                                 body=body,
#     402                                 **urlopen_kw)
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/influxdb_client/_sync/rest.py:304, in RESTClientObject.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout, **urlopen_kw)
#     301 def POST(self, url, headers=None, query_params=None, post_params=None,
#     302          body=None, _preload_content=True, _request_timeout=None, **urlopen_kw):
#     303     """Perform POST HTTP request."""
# --> 304     return self.request("POST", url,
#     305                         headers=headers,
#     306                         query_params=query_params,
#     307                         post_params=post_params,
#     308                         _preload_content=_preload_content,
#     309                         _request_timeout=_request_timeout,
#     310                         body=body,
#     311                         **urlopen_kw)
#
# File ~/.conda/envs/torch/lib/python3.8/site-packages/influxdb_client/_sync/rest.py:254, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout, **urlopen_kw)
#     251     logger.debug("response body: %s", r.data)
#     253 if not 200 <= r.status <= 299:
# --> 254     raise ApiException(http_resp=r)
#     256 return r
#
# ApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json; charset=utf-8', 'Vary': 'Accept-Encoding', 'X-Influxdb-Build': 'OSS', 'X-Influxdb-Version': '2.0.9', 'X-Platform-Error-Code': 'invalid', 'Date': 'Fri, 11 Nov 2022 00:35:16 GMT', 'Transfer-Encoding': 'chunked'})
# HTTP response body: b'{"code":"invalid","message":"error @4:59-4:60: undefined identifier d"}'

# %% [markdown]
# ## Use 2.0.9 version

# %%
end_time = last
start_time = first
number = 100
if version == 2:    
    data_limit_time = DBClient.get_data_limit_by_time(start_time, end_time, number, db_name, ms_name)
    data_limit_time

# %%
if version == 2: 
    data_count = DBClient.get_data_count(db_name, ms_name)
    print(data_count)
# Out:
# 656

# %% [markdown]
# ## Tag methods

# %%
db_name  = 'finance_korean_stock'

# %%
ms_list = DBClient.measurement_list(db_name)
print(ms_list)
# Out:
# ['stock']

# %%
ms_name = 'stock'

# %%
tag_list = DBClient.get_tagList(db_name, ms_name)
print(tag_list)
# Out:
# ['company', 'country', 'exchange', 'industry', 'ticker']

# %%
tag_key = 'company'
tag_distinct_value = DBClient.get_TagValue(db_name, ms_name, tag_key)
tag_distinct_value
# Out:
# ['AJ네트웍스',
#  'ASML 홀딩 NV ADR',
#  'AT&T 5.625% 글로벌 노트',
#  'AT&T Inc',
#  'Abb Ltd ADR',
#  'Afya Ltd Class A',
#  'Alliance Resource Partners LP Unit',
#  'BGF리테일',
#  'BHP 그룹',
#  'BHP 그룹 PLC ADR',
#  'BP PLC ADR',
#  'Brookfield Business Partners LP Unit',
#  'CAE Inc',
#  'CBRE 그룹 Class A',
#  'CJ',
#  'CJ CGV',
#  'CJ대한통운',
#  'CJ제일제당',
#  'CMS 에너지',
#  'CSX Corp',
#  'CVS 헬스',
#  'D.R.호턴',
#  'DB',
#  'DB손해보험',
#  'DB하이텍',
#  'DL이앤씨',
#  'ESR켄달스퀘어리츠',
#  'Enterprise Products Partners LP Unit',
#  'F&F',
#  'GKL',
#  'GS',
#  'GSX 테크에듀 ADR Class A',
#  'GS건설',
#  'GS글로벌',
#  'GS리테일',
#  'HCA 헬스케어',
#  'HMM',
#  'IPG 포터닉스',
#  'JD닷컴 ADR',
#  'KB금융',
#  'KCC',
#  'KG동부제철',
#  'KG케미칼',
#  'KODEX 200',
#  'KODEX 200선물인버스2X',
#  'KODEX 단기채권',
#  'KODEX 삼성그룹',
#  'KSS해운',
#  'KT',
#  'KT&G',
#  'KTcs',
#  'LG',
#  'LG디스플레이',
#  'LG상사',
#  'LG생활건강',
#  'LG생활건강우',
#  'LG유플러스',
#  'LG이노텍',
#  'LG전자',
#  'LG전자우',
#  'LG헬로비전',
#  'LG화학',
#  'LIG넥스원',
#  'MPLX LP Unit',
#  'MYT 네덜란드 패어런트 ADR',
#  'NAVER',
#  'NHN',
#  'NICE',
#  'NIO ADR Class A',
#  'Nuveen Amt-Free Quality Municipal Income Fund',
#  'PC 커넥션',
#  'PCN 파이낸셜 서비스',
#  'POSCO',
#  'PPL Corp',
#  'S&P 글로벌',
#  'S-Oil',
#  'SBS',
#  'SGC에너지',
#  'SK',
#  'SK가스',
#  'SK디스커버리',
#  'SK디앤디',
#  'SK렌터카',
#  'SK바이오사이언스',
#  'SK바이오팜',
#  'SK아이이테크놀로지',
#  'SK이노베이션',
#  'SK텔레콤',
#  'SK하이닉스',
#  'STX',
#  'Sprott Physical Gold Trust',
#  'T-모바일 US',
#  'TAL 에듀케이션 그룹 ADR Class A',
#  'TC 에너지',
#  'TIGER 200',
#  'TJX 컴퍼니스',
#  'U.S. 뱅코프',
#  'UFP 인더스트리',
#  'UGI Crop',
#  'United Parcel Service Inc Class B',
#  'VF Corp',
#  'Vanguard Global ex-US Real Estate Index Fd;ETF',
#  '가민',
#  '강원랜드',
#  '경동나비엔',
#  '경인전자',
#  '고려아연',
#  '골드만삭스',
#  '그랜드 캐넌 에듀케이션',
#  '그레이엄 홀딩스 Class B',
#  '그루포 아에로포르투아리오 센트로 노테 ADR Series B',
#  '그루포 에어로포르투아리오 수레스테 ADR',
#  '글로벌 인더스트리얼',
#  '글로벌 페이먼츠',
#  '금강공업',
#  '금호석유',
#  '기아',
#  '기업은행',
#  '깨끗한나라',
#  '나이키 Class B',
#  '내셔널 그리드 ADR',
#  '내셔털 퓨얼 가스',
#  '넥스젠 에너지',
#  '넥스트에라 에너지',
#  '넷마블',
#  '노바티스 AG ADR',
#  '노스톱 그루만',
#  '노키아 Oyj ADR',
#  '뉴 오리엔탈 에듀케이션 & 테크놀로지 그룹ADR',
#  '뉴 포트리스 에너지 Class A',
#  '뉴웰브랜즈',
#  '다나허',
#  '다우',
#  '다우기술',
#  '대교',
#  '대교우B',
#  '대덕',
#  '대덕1우',
#  '대림B&Co',
#  '대림통상',
#  '대성홀딩스',
#  '대우건설',
#  '대우조선해양',
#  '대한항공',
#  '대한해운',
#  '더블유게임즈',
#  '더존비즈온',
#  '데니슨 마인스',
#  '데시페라 파머수티컬스',
#  '덴티움',
#  '델타 에어라인스',
#  '델테크놀로지 Class C',
#  '도미니언 에너지',
#  '도요타자동차 ADR',
#  '동국제강',
#  '동방',
#  '동서',
#  '동양고속',
#  '동양생명',
#  '동원시스템즈',
#  '두산밥캣',
#  '두산인프라코어',
#  '두산중공업',
#  '두산퓨얼셀',
#  '듀크 에너지',
#  '드림텍',
#  '디아지오 ADR',
#  '디어',
#  '라르고 리소시스',
#  '라이언에어 홀딩스 ADR',
#  '락앤락',
#  '레나 Class A',
#  '레이테온 테크놀로지스',
#  '로리어트 에듀케이션 Class A',
#  '로스 스토어스',
#  '로얄 더치 쉘 ADR Class A',
#  '로우스 컴퍼니',
#  '로쿠',
#  '록히드 마틴',
#  '롯데관광개발',
#  '롯데리츠',
#  '롯데쇼핑',
#  '롯데지주',
#  '롯데칠성',
#  '롯데케미칼',
#  '롯데하이마트',
#  '루이지애니-퍼시픽',
#  '룰루레몬 애슐레티카',
#  '리바이 스트라우스 Class A',
#  '리버티 브로드밴드 Series A',
#  '리샹 에듀케이션 홀딩 ADR',
#  '리오 틴토 ADR',
#  '리타 파머수티컬스',
#  '린드',
#  '마쉬 앤 맥레넌 컴퍼니',
#  '마스텍',
#  '마이크로소프트',
#  '마틴 마리에타 머터리얼스',
#  '만도',
#  '매리어트 인터내셔널',
#  '매스코',
#  '맥도날드',
#  '맥커 아웃도어',
#  '맥쿼리 인프라스트럭처',
#  '맥쿼리인프라',
#  '메드트로닉',
#  '메리츠금융지주',
#  '메리츠증권',
#  '메리츠화재',
#  '메케슨',
#  '메틀러 톨레도 인터내셔널',
#  '모간스탠리',
#  '모나리자',
#  '모나미',
#  '모토로라 솔루션스',
#  '모호크 인더스트리스',
#  '몬델리즈 인터내셔널 Class A',
#  '무디스',
#  '무림P&P',
#  '무학',
#  '미들비',
#  '미래에셋생명',
#  '미래에셋증권',
#  '바스타 플랫폼 Class A',
#  '바이콤CBS Class B',
#  '발레 SA ADR',
#  '발칸 머티리얼스',
#  '뱅크오브아메리카',
#  '버라이존 커뮤니케이션스',
#  '버크셔 해서웨이 Class A',
#  '버크셔 해서웨이 Class B',
#  '보잉',
#  '보해양조',
#  '볼',
#  '부산가스',
#  '부킹 홀딩스',
#  '뷰티 헬스 Class A',
#  '브로드리지 파이낸셜 솔루션스',
#  '브로드컴',
#  '브리티쉬 아메리칸 토바코 ADR',
#  '블랙록',
#  '블랙스톤 그룹',
#  '블루프린트 메디슨스',
#  '비상교육',
#  '비자 Class A',
#  '비케이탑스',
#  '비트루',
#  '사네아멘투 바지쿠 두 에스타두 ADR',
#  '사우스웨스트 에어라인스',
#  '삼성SDI',
#  '삼성SDI우',
#  '삼성물산',
#  '삼성바이오로직스',
#  '삼성생명',
#  '삼성에스디에스',
#  '삼성엔지니어링',
#  '삼성전기',
#  '삼성전자',
#  '삼성전자우',
#  '삼성중공업',
#  '삼성증권',
#  '삼성출판사',
#  '삼성카드',
#  '삼성화재',
#  '삼양패키징',
#  '삼익악기',
#  '삼정펄프',
#  '삼화콘덴서',
#  '샘프라 에너지',
#  '서던',
#  '서울가스',
#  '서흥',
#  '선런',
#  '성창기업지주',
#  '세멘토스 파카스마요',
#  '세방',
#  '세아베스틸',
#  '세우글로벌',
#  '셀트리온',
#  '셔윈-윌리엄즈',
#  '소니 그룹 ADR',
#  '솔라에지 테크놀로지스',
#  '솔루스첨단소재',
#  '솔루엠',
#  '수지노 SA ADR',
#  '쉐브론',
#  '스타벅스',
#  '스텔란티스',
#  '스톤코 Class A',
#  '슬럼버거',
#  '시그나',
#  '시멕스 SAB de CV ADR',
#  '시스코',
#  '시스코 시스템즈',
#  '시어 Class A',
#  '신도리코',
#  '신세계',
#  '신세계 I&C',
#  '신세계인터내셔날',
#  '신송홀딩스',
#  '신한지주',
#  '신흥',
#  '쌍용C&E',
#  '써모 피셔 사이언티픽',
#  '쓰리엠',
#  '씨아이테크',
#  '씨에스윈드',
#  '아남전자',
#  '아레나 파마슈티컬스',
#  '아레스 캐피털',
#  '아르코 플랫폼',
#  '아마존닷컴',
#  '아메리칸 스테이츠 워터',
#  '아메리칸 에어라인스 그룹',
#  '아메리칸 워터 웍스',
#  '아메리칸 타워',
#  '아모레G',
#  '아모레퍼시픽',
#  '아세아제지',
#  '아이마켓코리아',
#  '아치 콜',
#  '알루코',
#  '알리바바 그룹 홀딩스 ADR',
#  '알파 메탈러지컬 리소시스',
#  '암베브 SA ADR',
#  '암페놀',
#  '애보트 레버러토리',
#  '애스트 스페이스모바일 Class A',
#  '애이콤 테크놀러지',
#  '애트모스 에너지',
#  '앤섬',
#  '에너지 퓨얼스',
#  '에넥스',
#  '에머슨 일렉트릭',
#  '에브비',
#  '에센셀 유틸리티스',
#  '에스디바이오센서',
#  '에스원',
#  '에스티 로더',
#  '에어 프로덕츠 앤드 케미컬스',
#  '에이버리 데니슨',
#  '에이온',
#  '에코랩',
#  '엑셀론',
#  '엑슨 모빌',
#  '엔비디아',
#  '엔씨소프트',
#  '엔에스쇼핑',
#  '엔에이치스팩19호',
#  '엠씨넥스',
#  '엠코',
#  '영원무역',
#  '영풍',
#  '오뚜기',
#  '오레일리 오토모티브',
#  '오리엔트바이오',
#  '오리온',
#  '오링크 홀딩 AB ADR',
#  '오픈도어 테크놀로지스 Class A',
#  '우리금융지주',
#  '우리종금',
#  '웅진싱크빅',
#  '원 가스',
#  '월그린스 부츠 얼라이언스',
#  '월마트',
#  '월트 디즈니',
#  '월풀',
#  '웨스턴 디지털',
#  '웨스트 프레이저 팀버',
#  '웨이스트 매니지먼트',
#  '웰스파고',
#  '윌리엄스 컴퍼니즈',
#  '유나이티드 에어라인스 홀딩스',
#  '유니레버 ADR',
#  '유니온 퍼시픽',
#  '율촌화학',
#  '이노션',
#  '이마트',
#  '이튼',
#  '인터내셔널 플레이버스 & 프레그린스',
#  '인터내셔털 페이퍼',
#  '인텔',
#  '인튜이티브 서지컬',
#  '인페이즈 에너지',
#  '일라이 릴리',
#  '일진다이아',
#  '일진디스플',
#  '일진머티리얼즈',
#  '제너럴 다이내믹스',
#  '제너럴 모터스',
#  '제너럴 일렉트릭',
#  '제이알글로벌리츠',
#  '제이콘텐트리',
#  '제이콥스엔지니어링',
#  '제이피모간체이스',
#  '제일기획',
#  '제임스 하디 인더스트리스 ADR',
#  '제주항공',
#  '존스 랭 라살',
#  '존슨앤드존슨',
#  '주연테크',
#  '지누스',
#  '지브라 테크놀로지스 Class A',
#  '지역난방공사',
#  '지투알',
#  '진에어',
#  '진원생명과학',
#  '질로우 그룹 Class C',
#  '차터 커뮤니케이션',
#  '찰스 슈왑',
#  '처브',
#  '천일고속',
#  '치포틀레 멕시칸 그릴',
#  '카바나 Class A',
#  '카에코',
#  '카카오',
#  '캐논 ADR',
#  '캘리포니아 워터 서비스 그룹',
#  '커네디언 내셔널 레일웨이',
#  '컴캐스트',
#  '케이씨씨글라스',
#  '코닝',
#  '코스트코 홀세일',
#  '코웨이',
#  '코인베이스 글로벌 Class A',
#  '코카콜라',
#  '코퍼래시온 어메리카 에어포츠',
#  '콘솔 에너지',
#  '콜게이트-팜올리브',
#  '콴타 서비스',
#  '쿠쿠홀딩스',
#  '쿠쿠홈시스',
#  '큐리그 닥터 페퍼',
#  '큐어백 NV',
#  '크라운 캐슬 인터내셔널',
#  '크라운 홀딩스',
#  '크래프트 하인즈',
#  '크로거',
#  '크로락스',
#  '키다리스튜디오',
#  '키움증권',
#  '타겟',
#  '타이완 반도체 메뉴펙처링 ADR',
#  '테슬라',
#  '테이크-투 인터랙티브 소프트웨어',
#  '텔레다인 테크놀로지스',
#  '텔레폰악티에볼라예트 LM 에릭슨 ADR Class B',
#  '텔코웨어',
#  '템퍼 실리 인터내셔널',
#  '토탈에너지스 SE. ADR',
#  '투심플 홀딩스 Class A',
#  '트리니티 인더스트리스',
#  '티웨이항공',
#  '파이서브',
#  '팬오션',
#  '퍼블릭 서비스 앤터프라이즈',
#  '퍼블릭 스토리지',
#  '퍼스텍',
#  '퍼스트 솔라',
#  '퍼스트 하이스쿨 에듀케이션 그룹 ADR Class A',
#  '퍼시스',
#  '페덱스',
#  '페이스북',
#  '페이팔 홀딩스',
#  '펠로튼 인터랙티브 Class A',
#  '펩시코',
#  '포스코강판',
#  '포스코인터내셔널',
#  '포스코케미칼',
#  '포춘 브랜즈 홈 & 시큐리티',
#  '폴',
#  '폴라리스',
#  '폴티 그룹',
#  '푸르덴셀 ADR',
#  '푸투 홀딩스 ADR',
#  '풍산',
#  '프로그레시브',
#  '프로로지스',
#  '프록터 & 겜블',
#  '프리포트 맥모란',
#  '플러그 파워',
#  '피델리티 내셔널 인포메이션 서비스',
#  '피바디 에너지',
#  '필립 모리스 인터내셔널',
#  '하나금융지주',
#  '하나웰 인터내셔널',
#  '하나투어',
#  '하이량 에듀케이션 그룹 ADR',
#  '하이브',
#  '하이트론',
#  '하이트진로',
#  '하이트진로홀딩스',
#  '한국가스공사',
#  '한국공항',
#  '한국금융지주',
#  '한국자산신탁',
#  '한국전력',
#  '한국조선해양',
#  '한국카본',
#  '한국콜마',
#  '한국타이어앤테크놀로지',
#  '한국항공우주',
#  '한미반도체',
#  '한미사이언스',
#  '한샘',
#  '한솔제지',
#  '한솔홀딩스',
#  '한온시스템',
#  '한일시멘트',
#  '한일현대시멘트',
#  '한전KPS',
#  '한전기술',
#  '한전산업',
#  '한진',
#  '한진칼',
#  '한화',
#  '한화생명',
#  '한화솔루션',
#  '한화시스템',
#  '한화에어로스페이스',
#  '헤즈브로',
#  '현대건설',
#  '현대그린푸드',
#  '현대글로비스',
#  '현대로템',
#  '현대리바트',
#  '현대모비스',
#  '현대미포조선',
#  '현대에너지솔루션',
#  '현대오토에버',
#  '현대위아',
#  '현대제철',
#  '현대중공업지주',
#  '현대차',
#  '현대차2우B',
#  '현대차우',
#  '현대코퍼레이션',
#  '현대코퍼레이션홀딩스',
#  '현대해상',
#  '현대홈쇼핑',
#  '호텔신라',
#  '홈디포',
#  '홍아해운',
#  '화이자',
#  '효성',
#  '효성ITX',
#  '효성티엔씨',
#  '휠라홀딩스',
#  '휴렛 패커드',
#  '휴마나']

# %%
tag_value='컴캐스트'
tag_value_data = DBClient.get_data(db_name, ms_name, tag_key, tag_value)
tag_value_data
# Out:
#                           company country exchange  industry ticker  \
# time
# 2021-12-01 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2021-12-16 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2021-12-17 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2021-12-20 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2021-12-21 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2021-12-22 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2021-12-23 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2021-12-27 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2021-12-28 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2021-12-29 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2021-12-30 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2021-12-31 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-01-03 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-01-04 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-01-05 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-01-06 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-01-07 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-01-10 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-01-11 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-01-12 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-01-13 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-01-14 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-02-03 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-02-04 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-02-07 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-02-08 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-02-09 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-02-11 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-02-14 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-02-15 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-02-16 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-02-24 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-02-25 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-02-28 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-03-01 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-03-02 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-03-03 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-03-04 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-03-07 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-03-08 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-03-10 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
# 2022-03-11 00:00:00+00:00    컴캐스트      US   NASDAQ  미디어 및 출판  CMCSA
#
#                            adj_close_value  close_value  high_value  \
# time
# 2021-12-01 00:00:00+00:00        49.080002    49.080002   51.400002
# 2021-12-16 00:00:00+00:00        48.840000    48.840000   49.520000
# 2021-12-17 00:00:00+00:00        48.750000    48.750000   49.250000
# 2021-12-20 00:00:00+00:00        48.400002    48.400002   48.674999
# 2021-12-21 00:00:00+00:00        48.860001    48.860001   49.314999
# 2021-12-22 00:00:00+00:00        49.029999    49.029999   49.160000
# 2021-12-23 00:00:00+00:00        50.029999    50.029999   50.215000
# 2021-12-27 00:00:00+00:00        50.470001    50.470001   50.590000
# 2021-12-28 00:00:00+00:00        50.509998    50.509998   51.020000
# 2021-12-29 00:00:00+00:00        50.590000    50.590000   50.764999
# 2021-12-30 00:00:00+00:00        50.590000    50.590000   51.200001
# 2021-12-31 00:00:00+00:00        50.330002    50.330002   51.279999
# 2022-01-03 00:00:00+00:00        50.740002    50.740002   50.950001
# 2022-01-04 00:00:00+00:00        50.189999    50.189999   51.020000
# 2022-01-05 00:00:00+00:00        50.220001    50.220001   51.200001
# 2022-01-06 00:00:00+00:00        50.509998    50.509998   50.980000
# 2022-01-07 00:00:00+00:00        50.049999    50.049999   50.580002
# 2022-01-10 00:00:00+00:00        50.520000    50.520000   50.919998
# 2022-01-11 00:00:00+00:00        51.139999    51.139999   51.180000
# 2022-01-12 00:00:00+00:00        50.950001    50.950001   51.689999
# 2022-01-13 00:00:00+00:00        51.279999    51.279999   51.680000
# 2022-01-14 00:00:00+00:00        51.680000    51.680000   52.099998
