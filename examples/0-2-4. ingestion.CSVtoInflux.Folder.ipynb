# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import" data-toc-modified-id="Import-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import</a></span></li><li><span><a href="#1.-Setting-Parameter" data-toc-modified-id="1.-Setting-Parameter-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>1. Setting Parameter</a></span></li><li><span><a href="#Data-Collect" data-toc-modified-id="Data-Collect-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Collect</a></span></li><li><span><a href="#3.-Example-Input-Data" data-toc-modified-id="3.-Example-Input-Data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>3. Example Input Data</a></span></li><li><span><a href="#4.-Example-Save-Data" data-toc-modified-id="4.-Example-Save-Data-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>4. Example Save Data</a></span></li></ul></div>

# %% [markdown]
# # Import

# %%
import pandas as pd
import os
import sys

sys.path.append("../")
sys.path.append("../..")

from Clust.setting.influx_setting_KETI import CLUSTDataServer2 as ins
from Clust.clust.ingestion.influx import influx_Client_v2 as iC

import Clust.clust.ingestion.CSVtoInflux.csvCollector as cC

# %% [markdown]
# # 1. Setting Parameter

# %% [markdown]
# - parameter 는 KETIPreDataCollection.collectorParameter 의 parameter 로 호출 가능
# ```
# ###예시###
# import KETIPreDataCollection.collectorParameter as cP
# cP.parameter
# ```

# %%
####### db connection parameter
db_client = iC.influxClient(ins)

# %%
####### Folder / File 업로드 방식 고르시
upload_type_list = ["File", "Folder"]
upload_type = upload_type_list[1]

# %%
####### read&clean type 고르기 parameter
data_read_type_list = ["basic", "selectedData", "highCapacity"]
data_read_type = data_read_type_list[2]

# %%
####### 기본 Data 관련 저장에 필요한 정보 기입
db_name = "test_data_type4"
ms_name = None
path = "./exampleData/Type4_FolderData"
encoding = "cp949"

# %%
####### 저장될 데이터의 시간 스템프로 지정될 column 을 기입하는 parameter
time_column = "in_tm"

# %%
####### clean type 에 따라 data read type의 parameter 가 달라짐
selected_datas =  None

# %%
####### 저장하는 column 선택하는 parameter
selected_columns = ['in_temp', 'in_humi', 'in_co2', 'in_voc', 'in_noise', 'in_pm10', 'in_pm25', 'in_pm01']

# %%
####### duplicated time column processing method 정하는 parameter
dtcpm = None

# %%
####### 데이터  parameter
field_type = "float"

# %%
####### 최종 Parameter
parameter = {
    "uploadType" : upload_type,
    "dataReadType" : data_read_type,
    "dbName" : db_name,
    "msName" : ms_name,
    "filePath" : path,
    "selectedDatas" : selected_datas, # data read type 이 selectedData 인 경우 필요한 param
    "timeColumnName" : time_column,
    "selectedColumns" : selected_columns,
    "duplicatedTimeColumnProcessingMethod" : dtcpm,
    "encoding" : encoding,
    "fieldType" : field_type
}
print("parameter success")
# Out:
# parameter success

# %% [markdown]
# # Data Collect

# %%
csv_collector = cC.Collector(parameter, db_client)
csv_collector.collect()
# Out:
# ############# count :  1  #############
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000020 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2020-04-03 03:45:00     19.5     31.0   585.0   108.0      29.0     24.0
# 2020-04-03 03:46:00     19.5     31.0   580.0   108.0      29.0     22.0
#
#                      in_pm25  in_pm01
# time
# 2020-04-03 03:45:00     16.0     13.0
# 2020-04-03 03:46:00     15.0     13.0
# /Users/jisoohwang/Desktop/Clust/Clust/examples/../../Clust/clust/ingestion/CSVtoInflux/csvCollector.py:131: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   self.get_high_capacity_data()
# ========== create bucket ==========
# ========== write success ==========
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000020 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2020-04-21 20:50:00     19.7     25.0   556.0     9.0      28.0      6.0
# 2020-04-21 20:51:00     19.7     25.0   549.0     9.0      28.0      5.0
#
#                      in_pm25  in_pm01
# time
# 2020-04-21 20:50:00      3.0      2.0
# 2020-04-21 20:51:00      3.0      2.0
# ========== write success ==========
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000020 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2020-05-10 09:31:00     23.8     46.0   569.0    31.0      28.0     10.0
# 2020-05-10 09:32:00     23.8     45.0   571.0    34.0      28.0      9.0
#
#                      in_pm25  in_pm01
# time
# 2020-05
00      0.0      0.0
# ========== write success ==========
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000018 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2021-05-12 04:44:00     22.7     25.0   370.0     4.0      52.0      1.0
# 2021-05-12 04:45:00     22.7     25.0   370.0     3.0      52.0      0.0
#
#                      in_pm25  in_pm01
# time
# 2021-05-12 04:44:00      1.0      1.0
# 2021-05-12 04:45:00      0.0      0.0
# ========== write success ==========
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000018 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2021-05-30 16:43:00     24.9     39.0   365.0    38.0      50.0      0.0
# 2021-05-30 16:44:00     24.9     39.0   364.0    40.0      50.0      1.0
#
#                      in_pm25  in_pm01
# time
# 2021-05-30 16:43:00      0.0      0.0
# 2021-05-30 16:44:00      0.0      0.0
# ========== write success ==========
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000018 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2021-06-17 05:10:00     28.0     44.0   358.0     7.0      51.0      6.0
# 2021-06-17 05:11:00     28.0     44.0   360.0     5.0      51.0      6.0
#
#                      in_pm25  in_pm01
# time
# 2021-06-17 05:10:00      3.0      2.0
# 2021-06-17 05:11:00      3.0      2.0
# ========== write success ==========
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000018 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2021-07-04 16:01:00     29.3     59.0   373.0    71.0      50.0      2.0
# 2021-07-04 16:02:00     29.3     59.0   375.0    70.0      51.0      2.0
#
#                      in_pm25  in_pm01
# time
# 2021-07-04 16:01:00      2.0      2.0
# 2021-07-04 16:02:00      2.0      2.0
# ========== write success ==========
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000018 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2021-07-22 04:30:00     32.7     53.0   387.0    29.0      47.0      6.0
# 2021-07-22 04:31:00     32.7     53.0   387.0    22.0      47.0      5.0
#
#                      in_pm25  in_pm01
# time
# 2021-07-22 04:30:00      5.0      5.0
# 2021-07-22 04:31:00      5.0      5.0
# ========== write success ==========
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000018 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2021-08-08 16:29:00     34.4     50.0   359.0   113.0      50.0      8.0
# 2021-08-08 16:30:00     34.4     50.0   359.0   122.0      49.0      8.0
#
#                      in_pm25  in_pm01
# time
# 2021-08-08 16:29:00      7.0      7.0
# 2021-08-08 16:30:00      7.0      7.0
# ========== write success ==========
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000018 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2021-08-26 05:38:00     29.5     58.0   416.0    40.0      49.0      2.0
# 2021-08-26 05:39:00     29.5     58.0   411.0    38.0      49.0      2.0
#
#                      in_pm25  in_pm01
# time
# 2021-08-26 05:38:00      2.0      2.0
# 2021-08-26 05:39:00      2.0      2.0
# ========== write success ==========
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000018 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2021-08-31 23:58:00     27.5     56.0   351.0   193.0      49.0      4.0
# 2021-08-31 23:59:00     27.4     56.0   357.0   195.0      49.0      2.0
#
#                      in_pm25  in_pm01
# time
# 2021-08-31 23:58:00      3.0      3.0
# 2021-08-31 23:59:00      2.0      2.0
# ========== write success ==========

# %% [markdown]
# # 3. Example Input Data

# %%
ex_data = pd.read_csv("./exampleData/Type4_FolderData/ICW0W2000019.csv", encoding = 'cp949')

# %%
ex_data.head()
# Out:
#               in_tm     in_serial  in_pm01_raw  in_pm25_raw  in_pm10_raw  \
# 0  2020/03/04 16:51  ICW0W2000019         61.0         68.0         85.0
# 1  2020/03/04 16:52  ICW0W2000019         60.0         67.0         86.0
# 2  2020/03/04 16:53  ICW0W2000019         59.0         66.0         85.0
# 3  2020/03/04 16:54  ICW0W2000019         57.0         63.0         79.0
# 4  2020/03/04 16:55  ICW0W2000019         58.0         64.0         78.0
#
#    in_temp  in_humi  in_co2  in_voc  in_noise  ...  in_pm01  in_cici_pm10  \
# 0     21.8     22.0   780.0     0.0      39.0  ...     61.0          77.0
# 1     22.3     21.0   740.0     0.0      39.0  ...     60.0          77.0
# 2     22.8     21.0   710.0     1.0      39.0  ...     59.0          77.0
# 3     23.2     20.0   703.0     3.0      39.0  ...     57.0          80.0
# 4     23.5     20.0   698.0     3.0      38.0  ...     58.0          80.0
#
#    in_cici_pm25  in_cici_co2  in_cici_voc  in_cici_temp  in_cici_humi  \
# 0          55.0         84.0        100.0          91.0          54.0
# 1          56.0         85.0        100.0          88.0          52.0
# 2          57.0         85.0        100.0          86.0          52.0
# 3          59.0         85.0        100.0          84.0          50.0
# 4          58.0         85.0        100.0          82.0          50.0
#
#    in_cici_noise  in_cici  in_ciai
# 0           86.0     79.0  -9999.0
# 1           86.0     77.0  -9999.0
# 2           86.0     77.0  -9999.0
# 3           86.0     77.0  -9999.0
# 4           86.0     76.0  -9999.0
#
# [5 rows x 22 columns]

# %% [markdown]
# # 4. Example Save Data

# %%
db_client = iC.influxClient(ins)
save_data = db_client.get_data(db_name, "ICW0W2000019")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/99/74g7dd5d0hbglxrqfzwk89cr0000gn/T/ipykernel_5088/3450010671.py in <module>
#       1 db_client = iC.influxClient(ins)
# ----> 2 save_data = db_client.get_data(db_name, "ICW0W2000019")
#
# ~/Desktop/Clust/Clust/examples/../../Clust/clust/ingestion/influx/influx_Client_v2.py in get_data(self, bk_name, ms_name, tag_key, tag_value)
#     156             '''
#     157         query_client = self.DBClient.query_api()
# --> 158         data_frame = query_client.query_data_frame(query)
#     159         data_frame = self.cleanup_df(data_frame)
#     160
#
# /opt/homebrew/Caskroom/miniforge/base/envs/Clust/lib/python3.8/site-packages/influxdb_client/client/query_api.py in query_data_frame(self, query, org, data_frame_index, params)
#     252         """  # noqa: E501
#     253         _generator = self.query_data_frame_stream(query, org=org, data_frame_index=data_frame_index, params=params)
# --> 254         return self._to_data_frames(_generator)
#     255
#     256     def query_data_frame_stream(self, query: str, org=None, data_frame_index: List[str] = None, params: dict = None):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/Clust/lib/python3.8/site-packages/influxdb_client/client/_base.py in _to_data_frames(self, _generator)
#     322             _dataFrames = _generator
#     323         else:
# --> 324             _dataFrames = list(_generator)
#     325
#     326         if len(_dataFrames) == 0:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/Clust/lib/python3.8/site-packages/influxdb_client/client/flux_csv_parser.py in generator(self)
#     113         """Return Python generator."""
#     114         with self as parser:
# --> 115             for val in parser._parse_flux_response():
#     116                 yield val
#     117
#
# /opt/homebrew/Caskroom/miniforge/base/envs/Clust/lib/python3.8/site-packages/influxdb_client/client/flux_csv_parser.py in _parse_flux_response(self)
#     123         metadata = _FluxCsvParserMetadata()
#     124
# --> 125         for csv in self._reader:
#     126             for val in self._parse_flux_response_row(metadata, csv):
#     127                 yield val
#
# /opt/homebrew/Caskroom/miniforge/base/envs/Clust/lib/python3.8/codecs.py in iterdecode(iterator, encoding, errors, **kwargs)
#    1051     """
#    1052     decoder = getincrementaldecoder(encoding)(errors, **kwargs)
# -> 1053     for input in iterator:
#    1054         output = decoder.decode(input)
#    1055         if output:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/Clust/lib/python3.8/site-packages/urllib3/response.py in __iter__(self)
#     806     def __iter__(self):
#     807         buffer = []
# --> 808         for chunk in self.stream(decode_content=True):
#     809             if b"\n" in chunk:
#     810                 chunk = chunk.split(b"\n")
#
# /opt/homebrew/Caskroom/miniforge/base/envs/Clust/lib/python3.8/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# /opt/homebrew/Caskroom/miniforge/base/envs/Clust/lib/python3.8/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     765                 if self.chunk_left == 0:
#     766                     break
# --> 767                 chunk = self._handle_chunk(amt)
#     768                 decoded = self._decode(
#     769                     chunk, decode_content=decode_content, flush_decoder=False
#
# /opt/homebrew/Caskroom/miniforge/base/envs/Clust/lib/python3.8/site-packages/urllib3/response.py in _handle_chunk(self, amt)
#     718             returned_chunk = value
#     719         else:  # amt > self.chunk_left
# --> 720             returned_chunk = self._fp._safe_read(self.chunk_left)
#     721             self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     722             self.chunk_left = None
#
# /opt/homebrew/Caskroom/miniforge/base/envs/Clust/lib/python3.8/http/client.py in _safe_read(self, amt)
#     611         IncompleteRead exception can be used to detect the problem.
#     612         """
# --> 613         data = self.fp.read(amt)
#     614         if len(data) < amt:
#     615             raise IncompleteRead(data, amt-len(data))
#
# /opt/homebrew/Caskroom/miniforge/base/envs/Clust/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
save_data.head()
