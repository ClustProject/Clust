# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import" data-toc-modified-id="Import-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import</a></span></li><li><span><a href="#1.-Setting-Parameter" data-toc-modified-id="1.-Setting-Parameter-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>1. Setting Parameter</a></span></li><li><span><a href="#Data-Collect" data-toc-modified-id="Data-Collect-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Collect</a></span></li><li><span><a href="#3.-Example-Input-Data" data-toc-modified-id="3.-Example-Input-Data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>3. Example Input Data</a></span></li><li><span><a href="#4.-Example-Save-Data" data-toc-modified-id="4.-Example-Save-Data-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>4. Example Save Data</a></span></li></ul></div>

# %% [markdown]
# # Import

# %%
import pandas as pd
import os
import sys

sys.path.append("../")
sys.path.append("../..")

from Clust.setting.influx_setting_KETI import CLUSTDataServer2 as ins
from Clust.clust.ingestion.influx import influx_Client_v2 as iC

import Clust.clust.ingestion.CSVtoInflux.csvCollector as cC

# %% [markdown]
# # 1. Setting Parameter

# %% [markdown]
# - parameter 는 KETIPreDataCollection.collectorParameter 의 parameter 로 호출 가능
# ```
# ###예시###
# import KETIPreDataCollection.collectorParameter as cP
# cP.parameter
# ```

# %%
####### db connection parameter
db_client = iC.influxClient(ins)

# %%
####### Folder / File 업로드 방식 고르시
upload_type_list = ["File", "Folder"]
upload_type = upload_type_list[1]

# %%
####### read&clean type 고르기 parameter
data_read_type_list = ["basic", "selectedData", "highCapacity"]
data_read_type = data_read_type_list[2]

# %%
####### 기본 Data 관련 저장에 필요한 정보 기입
db_name = "air_indoor_초등학교"
ms_name = None
path = "./Data Collection_Test Data Folder/Kweather_초등학교"
encoding = "cp949"

# %%
####### 저장될 데이터의 시간 스템프로 지정될 column 을 기입하는 parameter
time_column = "in_tm"

# %%
####### clean type 에 따라 data read type의 parameter 가 달라짐
selected_datas =  None

# %%
####### 저장하는 column 선택하는 parameter
selected_columns = ['in_temp', 'in_humi', 'in_co2', 'in_voc', 'in_noise', 'in_pm10', 'in_pm25', 'in_pm01']

# %%
####### duplicated time column processing method 정하는 parameter
dtcpm = None

# %%
####### 데이터  parameter
field_type = "float"

# %%
####### 최종 Parameter
parameter = {
    "uploadType" : upload_type,
    "dataReadType" : data_read_type,
    "dbName" : db_name,
    "msName" : ms_name,
    "filePath" : path,
    "selectedDatas" : selected_datas, # data read type 이 selectedData 인 경우 필요한 param
    "timeColumnName" : time_column,
    "selectedColumns" : selected_columns,
    "duplicatedTimeColumnProcessingMethod" : dtcpm,
    "encoding" : encoding,
    "fieldType" : field_type
}
print("parameter success")
# Out:
# parameter success

# %% [markdown]
# # Data Collect

# %%
csv_collector = cC.Collector(parameter, db_client)
csv_collector.collect()
# Out:
# ############# count :  1  #############
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000031 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2021-09-18 13:47:00     31.3       39     452      88        48        0
# 2021-09-18 13:48:00     31.3       39     442      87        49        0
#
#                      in_pm25  in_pm01
# time
# 2021-09-18 13:47:00        0        0
# 2021-09-18 13:48:00        0        0
# ========== create bucket ==========
# ========== write success ==========
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000031 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2021-10-05 23:47:00     25.8       52     489     224        48        8
# 2021-10-05 23:48:00     25.8       52     495     222        48        8
#
#                      in_pm25  in_pm01
# time
# 2021-10-05 23:47:00        7        7
# 2021-10-05 23:48:00        7        7
# ========== write success ==========
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000031 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2021-10-23
# ========== write success ==========
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000033 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2022-04-15 11:18:00     26.1       23     345      14        62       12
# 2022-04-15 11:19:00     26.1       23     341      12        60       12
#
#                      in_pm25  in_pm01
# time
# 2022-04-15 11:18:00        4        2
# 2022-04-15 11:19:00        4        2
# ========== write success ==========
# ===========data clean success===========
# Writing Data ...
# =========== ms name : ICW0W2000033 ===========
#                      in_temp  in_humi  in_co2  in_voc  in_noise  in_pm10  \
# time
# 2022-04-30 23:58:00     21.8       33     289      90        48        9
# 2022-04-30 23:59:00     21.8       33     285      88        48        8
#
#                      in_pm25  in_pm01
# time
# 2022-04-30 23:58:00        6        5
# 2022-04-30 23:59:00        6        5
# ========== write success ==========

# %% [markdown]
# # 3. Example Input Data

# %%
ex_data = pd.read_csv("./Data Collection_Test Data Folder/Kweather_초등학교/ICW0W2000030.csv", encoding = 'cp949')

# %%
ex_data.head()
# Out:
#                  in_tm     in_serial  in_pm01_raw  in_pm25_raw  in_pm10_raw  \
# 0  2021-09-01 15:42:00  ICW0W2000030            0            0            1
# 1  2021-09-01 15:43:00  ICW0W2000030            0            0            1
# 2  2021-09-01 15:44:00  ICW0W2000030            0            0            0
# 3  2021-09-01 15:45:00  ICW0W2000030            0            0            0
# 4  2021-09-01 15:46:00  ICW0W2000030            0            0            1
#
#    in_temp  in_humi  in_co2  in_voc  in_noise  ...  in_pm01  in_cici_pm10  \
# 0     19.3       69     571       0        50  ...        0          99.7
# 1     19.7       69     567       0        50  ...        0          99.7
# 2     20.0       69     570       0        50  ...        0         100.0
# 3     20.3       68     574       0        51  ...        0         100.0
# 4     20.6       67     581       0        51  ...        0          99.7
#
#    in_cici_pm25  in_cici_co2  in_cici_voc  in_cici_temp  in_cici_humi  \
# 0         100.0         87.7        100.0          94.5          83.6
# 1         100.0         87.8        100.0          95.9          83.6
# 2         100.0         87.8        100.0          96.9          83.6
# 3         100.0         87.7        100.0          97.9          84.2
# 4         100.0         87.6        100.0          99.0          84.8
#
#    in_cici_noise  in_cici  in_ciai
# 0           81.9      100       97
# 1           81.9      100       97
# 2           81.9      100       97
# 3           81.5      100       97
# 4           81.5      100       97
#
# [5 rows x 22 columns]

# %% [markdown]
# # 4. Example Save Data

# %%
db_client = iC.influxClient(ins)
save_data = db_client.get_data(db_name, "ICW0W2000030")

# %%
save_data.head()
# Out:
#                            in_co2  in_humi  in_noise  in_pm01  in_pm10  \
# time
# 2021-09-01 15:42:00+00:00     571       69        50        0        1
# 2021-09-01 15:43:00+00:00     567       69        50        0        1
# 2021-09-01 15:44:00+00:00     570       69        50        0        0
# 2021-09-01 15:45:00+00:00     574       68        51        0        0
# 2021-09-01 15:46:00+00:00     581       67        51        0        1
#
#                            in_pm25  in_temp  in_voc
# time
# 2021-09-01 15:42:00+00:00        0     19.3       0
# 2021-09-01 15:43:00+00:00        0     19.7       0
# 2021-09-01 15:44:00+00:00        0     20.0       0
# 2021-09-01 15:45:00+00:00        0     20.3       0
# 2021-09-01 15:46:00+00:00        0     20.6       0
