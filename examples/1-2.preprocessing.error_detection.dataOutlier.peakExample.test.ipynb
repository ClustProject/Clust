# %% [markdown]
# ### One Class SVM

# %%
from sklearn.svm import OneClassSVM
X = [[0], [0.44], [0.45], [0.46], [1]]
clf = OneClassSVM(gamma='auto').fit(X)
clf.predict(X)
clf.score_samples(X)
# Out:
# array([1.77987316, 2.05479873, 2.05560497, 2.05615569, 1.73328509])

# %% [markdown]
# ### Scipy.signal.find_peaks Test
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.find_peaks.html

# %%
import matplotlib.pyplot as plt
from scipy.misc import electrocardiogram
from scipy.signal import find_peaks
import numpy as np
x = electrocardiogram()[2000:4000]
height = -0.5

peaks, properties = find_peaks(x, height=height)
plt.plot(x)
plt.plot(peaks, x[peaks], "x")
plt.plot(np.zeros_like(x)+height, "--", color="gray")
plt.show()

# %%
plt.plot(properties['peak_heights'])

# %%
border = np.sin(np.linspace(0, 3 * np.pi, x.size))
peaks, properties = find_peaks(x, height=(-border, border))
plt.plot(x)
plt.plot(-border, "--", color="gray")
plt.plot(border, ":", color="gray")
plt.plot(peaks, x[peaks], "x")
plt.show()

# %%
plt.plot(properties['peak_heights'])

# %%
peaks, properties = find_peaks(x, distance=100)
np.diff(peaks)
plt.plot(x)
plt.plot(peaks, x[peaks], "x")
plt.show()

# %%
peaks, properties = find_peaks(x, prominence=(None, 0.3))
properties["prominences"].max()
plt.plot(x)
plt.plot(peaks, x[peaks], "x")
plt.show()
print(len(peaks))
# Out:
# 267

# %%
x = electrocardiogram()[17000:18000]
#x =data_col.reshape(-1)
peaks, properties = find_peaks(x, prominence=-1, width=1000)
print(properties["prominences"], properties["widths"])
plt.plot(x)
plt.plot(peaks, x[peaks], "x")
plt.vlines(x=peaks, ymin=x[peaks] - properties["prominences"],
           ymax = x[peaks], color = "C1")
plt.hlines(y=properties["width_heights"], xmin=properties["left_ips"],
           xmax=properties["right_ips"], color = "C1")
plt.show()
# Out:
# [] []
